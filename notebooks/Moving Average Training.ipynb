# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6/train_logs_1.txt')
no_shaping = res_df['success'].rolling(window=100).mean()
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_step_reward_15m/train_logs_1.txt')
shaping_15 = res_df['success'].rolling(window=100).mean()
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_step_reward_8m/train_logs_1.txt')
shaping_8 = res_df['success'].rolling(window=100).mean()

# %%
plt.plot(no_shaping)
plt.plot(shaping_15)
plt.plot(shaping_8)

# %%
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6/eval_push_logs_1.txt')
print(res_df['episode_length'].mean())
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_step_reward_15m/eval_push_logs_1.txt')
print(res_df['episode_length'].mean())
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_step_reward_8m/eval_push_logs_1.txt')
print(res_df['episode_length'].mean())
# Out:
# 53.11
# 55.645
# 57.865

# %%
res_df
# Out:
#       episode_length  episode_return  episodes   steps  steps_per_second  \
# 0                 12       -1.478495         1      12         16.419153
# 1                 18       -1.823874         2      30         64.783010
# 2                 13       -1.231768         3      43         70.085852
# 3                 18       -1.557501         4      61         67.185904
# 4                  8       -1.015629         5      69         73.999065
# ...              ...             ...       ...     ...               ...
# 9995              69        7.605247      9996  950937         33.850147
# 9996              61        7.064806      9997  950998         41.593680
# 9997             110        1.437540      9998  951108         36.246762
# 9998              61        4.464857      9999  951169         33.002036
# 9999              65        8.314861     10000  951234         41.570244
#
#       success
# 0       False
# 1       False
# 2       False
# 3       False
# ...

# %%
no_shaping = res_df['success'].rolling(window=100).mean()

# %%
plt.plot(res_df['success'].rolling(window=100).mean())

# %%
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_step_reward/train_logs_1.txt')
plt.plot(no_shaping)
plt.plot(res_df['success'].rolling(window=100).mean())

# %%
plt.plot(no_shaping)
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_9_objs/train_logs_1.txt')
plt.plot(res_df['success'].rolling(window=100).mean())

# %%
plt.plot(no_shaping)
res_df = pd.read_csv('../rl_agent/experiments/pose_easy_6_9_objs_further/train_logs_1.txt')
plt.plot(res_df['success'].rolling(window=100).mean())

# %%
l = [1.25, 1, 0.75, 0.5, 0.25]
print([90*x for x in l])
# Out:
# [112.5, 90, 67.5, 45.0, 22.5]

# %%
plt.plot(no_shaping)
res_df = pd.read_csv('../rl_agent/experiments_2/pose_easy_6_ori_correction/train_logs_1.txt')
plt.plot(res_df['success'].rolling(window=100).mean())
